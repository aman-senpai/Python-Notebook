# %% [markdown]
# # Debugging
#
# `pbd` implements an interactive debugging environment for Python programs. It includes features to let you pause program,look the values of variables, and watch program execute step-by-step, so you can understand what your program actually does and find bugs in the logic.
#
# # Starting the Debugger
#
# ### From the Command Line

# %%
def seq(n):
    for i in range(n):
        print(i)
    return

seq(5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # From Within Your Program

# %%
import pdb

# interactive debugging
def seq(n):
    for i in range(n):
        pdb.set_trace()     #brekpoint
        print(i)
    return

seq(5)

# c : continue
# q : quit
# h: help
# p : print
# p locals()
# p globals()
# Out:
# > /tmp/ipykernel_1805/2187574016.py(7)seq()
#       5     for i in range(n):
#       6         pdb.set_trace()     #brekpoint
# ----> 7         print(i)
#       8     return
#       9
#
#       2
#       3 # interactive debugging
#       4 def seq(n):
#       5     for i in range(n):
#       6         pdb.set_trace()     #brekpoint
# ----> 7         print(i)
#       8     return
#       9
#      10 seq(5)
#      11
#      12 # c : continue
#
# 0
# 5
# 0
# 5
# 0
# *** NameError: name 'local' is not defined
# <built-in function locals>
# <built-in function locals>
# {'n': 5, 'i': 0}
# 0
# > /tmp/ipykernel_1805/2187574016.py(6)seq()
#       4 def seq(n):
#       5     for i in range(n):
# ----> 6         pdb.set_trace()     #brekpoint
#       7         print(i)
#       8     return
#
#       1 import pdb
#       2
#       3 # interactive debugging
#       4 def seq(n):
#       5     for i in range(n):
# ----> 6         pdb.set_trace()     #brekpoint
#       7         print(i)
# ...

# %% [markdown]
# # Debugger Commands
#
# ## 1. `h`(elp) [command]
#
# Without argument, print the list of available commands. With a command as argument, print help abut that command. Help `pbd` displays the full documentataion (the docstring of the pdb module).
# Since the command argument must be an identifier, help exec must be entered to get help on the command.
#
# ## 2. `w`(here)
#
# Print a stack trace, with the most recent frame at the bottom. An arrow indicates the current frame, which determines the context of most commands.
#
# ## 3. `d`(own)[count]
#
# Move the current frame count (default one) down in the stack trace (to a newer frame).
#
# ## 4. `c`(cont(inue))
#
# Continue execution, only stop when a brekpoint is encountered.
#
# ## 5. `q`(uit)
#
# Quit from the debugger. The program being executed is aborted.
#
# # Terminal/Commnd prompt based debugging
